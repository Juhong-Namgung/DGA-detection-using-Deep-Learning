# %%
# Import lib
import pandas as pd
from sklearn.utils import shuffle

# %%
# Read dga.txt
alexa_file = pd.read_csv('alexa-top-1m.txt', header=None)
alexa_file.head()
# Out:
#              0
# 0   google.com
# 1  youtube.com
# 2    tmall.com
# 3       qq.com
# 4    baidu.com

# %%
# Process Alexa data
alexa_domains = alexa_file[0].tolist()

alexa_archive = pd.DataFrame()
alexa_archive['domain'] = alexa_domains
alexa_archive['source'] = "Alexa"
alexa_archive['class'] = 0

alexa_archive
# Out:
#                            domain source  class
# 0                      google.com  Alexa      0
# 1                     youtube.com  Alexa      0
# 2                       tmall.com  Alexa      0
# 3                          qq.com  Alexa      0
# 4                       baidu.com  Alexa      0
# ...                           ...    ...    ...
# 764161          viralnewstalk.com  Alexa      0
# 764162  wildlifepestsolutions.com  Alexa      0
# 764163         wonderfirstore.com  Alexa      0
# 764164               zapforex.com  Alexa      0
# 764165                zzang79.com  Alexa      0
#
# [764166 rows x 3 columns]

# %%
# Read dga.txt
dga_file = pd.read_csv('dga.txt', header=None)
dga_file.head()
# Out:
#                   0                                                  1  \
# 0  unpnqmvtcutt.com  Domain used by Cryptolocker - Flashback DGA fo...
# 1  ijuvteiotncj.net  Domain used by Cryptolocker - Flashback DGA fo...
# 2  vifuvwurqtlh.biz  Domain used by Cryptolocker - Flashback DGA fo...
# 3   jekdyohmimtw.ru  Domain used by Cryptolocker - Flashback DGA fo...
# 4  yvvlerfvescw.org  Domain used by Cryptolocker - Flashback DGA fo...
#
#             2                                                  3
# 0  2020-06-28  http://osint.bambenekconsulting.com/manual/cl.txt
# 1  2020-06-28  http://osint.bambenekconsulting.com/manual/cl.txt
# 2  2020-06-28  http://osint.bambenekconsulting.com/manual/cl.txt
# 3  2020-06-28  http://osint.bambenekconsulting.com/manual/cl.txt
# 4  2020-06-28  http://osint.bambenekconsulting.com/manual/cl.txt

# %%
def extract_source(source):
    return str(source).split()[3]

dga_archive = pd.DataFrame()
dga_archive['domain'] = dga_file[0]
dga_archive['source'] = dga_file[1].map(extract_source)

# Extract DGA classes
source_counts = dga_archive['source'].value_counts(sort=True)
print(source_counts)

dga_classes_dict = dict()

for i in range(15):
    # top 15 class
    dga_classes_dict[source_counts.index[i]] = i + 1
    
print(dga_classes_dict)

def is_class(source):
    return (source in dga_classes_dict)

def extract_class(source):
    return dga_classes_dict[source]

# Use only top 15 class domain
dga_archive = dga_archive[dga_archive['source'].map(is_class)]
dga_archive['class'] = dga_archive['source'].map(extract_class)

dga_archive
# Out:
# tinba                     66789
# Post                      66000
# ramnit                    64605
# necurs                    49152
# qakbot                    40000
# murofet                   28520
# shiotob/urlzone/bebloh    15021
# monerodownloader          14975
# ranbyus                   13960
# kraken                     8988
# dyre                       7998
# Cryptolocker               6000
# locky                      5352
# vawtrak                    3150
# P2P                        3000
# qadars                     2400
# ramdo                      2000
# pushdo                     1680
# chinad                     1536
# Volatile                    996
# proslikefan                 780
# pitou                       776
# sphinx                      768
# dircrypt                    720
# fobber                      600
# geodo                       576
# padcrypt                    576
# zloader                     576
# Tinynuke                    576
# symmi                       384
# MyDoom                      349
# mydoom                      349
# beebone                     300
# corebot                     280
# tempedreve                  249
# bamital                     240
# vidro                       200
# hesperbot                   192
# unknownjs                   180
# bedep                       172
# pandabanker                  96
# cryptowall                   94
# an                           70
# unknowndropper               60
# sisron                       60
# kingminer                    30
# gozi                         24
# mirai                         3
# xshellghost                   2
# dromedan                      2
# madmax                        2
# g01                           1
# Name: source, dtype: int64
# {'necurs': 4, 'Cryptolocker': 12, 'ranbyus': 9, 'P2P': 15, 'dyre': 11, 'ramnit': 3, 'tinba': 1, 'Post': 2, 'murofet': 6, 'kraken': 10, 'monerodownloader': 8, 'vawtrak': 14, 'locky': 13, 'qakbot': 5, 'shiotob/urlzone/bebloh': 7}
#                            domain            source  class
# 0                unpnqmvtcutt.com      Cryptolocker     12
# 1                ijuvteiotncj.net      Cryptolocker     12
# 2                vifuvwurqtlh.biz      Cryptolocker     12
# 3                 jekdyohmimtw.ru      Cryptolocker     12
# 4                yvvlerfvescw.org      Cryptolocker     12
# ...                           ...               ...    ...
# 410796  fffffd127b3b3.blackfriday  monerodownloader      8
# 410797     fffffd127b3b3.feedback  monerodownloader      8
# 410798      fffffd127b3b3.hosting  monerodownloader      8
# 410799          fffffd127b3b3.org  monerodownloader      8
# 410800      fffffd127b3b3.tickets  monerodownloader      8
#
# [393510 rows x 3 columns]

# %%
# Combine Alexa and DGA data
result = pd.concat([alexa_archive, dga_archive], sort=False)

# Shuffle and save the labeled data
result = shuffle(result, random_state=33)
result.to_csv("./dga_label.csv", mode='w', index=False)

result.head()
